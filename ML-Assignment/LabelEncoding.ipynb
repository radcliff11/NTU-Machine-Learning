# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv('C:\\Users\\byeby\\Desktop\\cz4041\\train.csv')

# %%
data
# Out:
#             id  bin_0  bin_1  bin_2 bin_3 bin_4  nom_0      nom_1    nom_2  \
# 0            0      0      0      0     T     Y  Green   Triangle    Snake
# 1            1      0      1      0     T     Y  Green  Trapezoid  Hamster
# 2            2      0      0      0     F     Y   Blue  Trapezoid     Lion
# 3            3      0      1      0     F     Y    Red  Trapezoid    Snake
# 4            4      0      0      0     F     N    Red  Trapezoid     Lion
# ...        ...    ...    ...    ...   ...   ...    ...        ...      ...
# 299995  299995      0      0      0     T     N    Red  Trapezoid    Snake
# 299996  299996      0      0      0     F     Y  Green  Trapezoid     Lion
# 299997  299997      0      0      0     F     Y   Blue       Star  Axolotl
# 299998  299998      0      1      0     F     Y  Green     Square  Axolotl
# 299999  299999      0      0      0     F     Y   Blue  Trapezoid      Dog
#
# ...

# %%
trainX,trainY = data.iloc[:,0:24],data.iloc[:,-1]
print(trainX.shape[0],trainX.shape[1])
# Out:
# 300000 24

# %%
trainX
# Out:
#             id  bin_0  bin_1  bin_2 bin_3 bin_4  nom_0      nom_1    nom_2  \
# 0            0      0      0      0     T     Y  Green   Triangle    Snake
# 1            1      0      1      0     T     Y  Green  Trapezoid  Hamster
# 2            2      0      0      0     F     Y   Blue  Trapezoid     Lion
# 3            3      0      1      0     F     Y    Red  Trapezoid    Snake
# 4            4      0      0      0     F     N    Red  Trapezoid     Lion
# ...        ...    ...    ...    ...   ...   ...    ...        ...      ...
# 299995  299995      0      0      0     T     N    Red  Trapezoid    Snake
# 299996  299996      0      0      0     F     Y  Green  Trapezoid     Lion
# 299997  299997      0      0      0     F     Y   Blue       Star  Axolotl
# 299998  299998      0      1      0     F     Y  Green     Square  Axolotl
# 299999  299999      0      0      0     F     Y   Blue  Trapezoid      Dog
#
# ...

# %%
trainY
# Out:
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#          ..
# 299995    0
# 299996    0
# 299997    1
# 299998    1
# 299999    0
# Name: target, Length: 300000, dtype: int64

# %%
trainLabelX = pd.DataFrame()
label=LabelEncoder()
for c in trainX.columns:
    if(trainX[c].dtype == 'object'):
        trainLabelX[c] = label.fit_transform(trainX[c])
    else:
        trainLabelX[c] = trainX[c]

# %%
from sklearn.linear_model import LogisticRegression as lg
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


X_train,X_test,y_train,y_test=train_test_split(trainLabelX,trainY,random_state=42,test_size=0.2)
lr=lg()
lr.fit(X_train,y_train)
y_pre=lr.predict(X_test)
print(accuracy_score(y_test,y_pre))
# Out:
# 0.69065

# %%
testX = pd.read_csv('C:\\Users\\byeby\\Desktop\\cz4041\\test.csv')
testXlabel = pd.DataFrame()
for c in testX.columns:
    if testX[c].dtype == 'object':
        testXlabel[c] = label.fit_transform(testX[c])
    else:
        testXlabel[c] = testX[c]
print(testX.shape[0],testX.shape[1])
# Out:
# 200000 24

# %%
test_target = lr.predict_proba(testXlabel)[:,1]
test_target
# Out:
# array([0.33235947, 0.34732511, 0.42370532, ..., 0.32853179, 0.15632708,
#        0.23657657])

# %%
submission = pd.read_csv('C:\\Users\\byeby\\Desktop\\cz4041\\sample_submission.csv')
submission['target'] = test_target
submission.to_csv('label_model.csv')

submission
# Out:
#             id    target
# 0       300000  0.332359
# 1       300001  0.347325
# 2       300002  0.423705
# 3       300003  0.334584
# 4       300004  0.242730
# ...        ...       ...
# 199995  499995  0.128803
# 199996  499996  0.128996
# 199997  499997  0.328532
# 199998  499998  0.156327
# 199999  499999  0.236577
#
# [200000 rows x 2 columns]
